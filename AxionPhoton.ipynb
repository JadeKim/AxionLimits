# %% [markdown]
# # Axion-photon coupling limits vs axion mass
#
# Axion mass-PQ scale relation:
# \begin{equation}
# m_{a}=5.70(7) \mu \mathrm{eV}\left(\frac{10^{12} \,\mathrm{GeV}}{f_{a}}\right)
# \end{equation}
#
# Axion-photon coupling
# \begin{equation}
# g_{a \gamma} \equiv \frac{\alpha}{2 \pi} \frac{C_{a\gamma}}{f_{a}}=2.0 \times 10^{-16} C_{a \gamma} \frac{m_{a}}{\mu \mathrm{eV}} \mathrm{GeV}^{-1}
# \end{equation}
#
# Model dependent constant:
# \begin{equation}
# C_{a\gamma} \equiv \frac{E}{N} - 1.92(4) =
# \begin{cases}
#   -1.92, & {\rm KSVZ} \\
#   0.75, & {\rm DFSZ\,I} \\
#   -1.25, & {\rm DFSZ\,II}
# \end{cases}
# \end{equation}

# %%
# %matplotlib inline
from numpy import *
import matplotlib.pyplot as plt
from PlotFuncs import BlackHoleSpins, AxionPhoton, MySaveFig


fig,ax = AxionPhoton.FigSetup(Shape='Rectangular',ylab='$|g_{a\gamma}|$ [GeV$^{-1}$]',mathpazo=True)
AxionPhoton.QCDAxion(ax)
AxionPhoton.QCDAxion_NonAbelianMonopole(ax)
AxionPhoton.Cosmology(ax)
AxionPhoton.StellarBounds(ax)
AxionPhoton.Haloscopes(ax,projection=False)
AxionPhoton.Helioscopes(ax,projection=False)
AxionPhoton.LSW(ax,projection=False)
AxionPhoton.AstroBounds(ax,projection=False)
AxionPhoton.NeutronStars(ax)
BlackHoleSpins(ax,(1/137)*(1/(2*pi)),[5e-12,2e-17],rotation=-90)

MySaveFig(fig,'AxionPhoton')
# Out:
# /Users/Ace/Desktop/AxionLimits/PlotFuncs.py:82: MatplotlibDeprecationWarning: Support for setting the 'text.latex.preamble' or 'pgf.preamble' rcParam to a list of strings is deprecated since 3.3 and will be removed two minor releases later; set it to a single string instead.
#   mpl.rcParams['text.latex.preamble'] = [r'\usepackage{mathpazo}']
# /Users/Ace/Desktop/AxionLimits/PlotFuncs.py:150: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("YlOrBr").copy()
#   cols.set_under('w') # Set lowest color to white

# %%
fig,ax = AxionPhoton.FigSetup(Shape='Rectangular',ylab='$|g_{a\gamma}|$ [GeV$^{-1}$]',mathpazo=True)

AxionPhoton.QCDAxion(ax,text_on=False)
AxionPhoton.QCDAxion_NonAbelianMonopole(ax)
AxionPhoton.Cosmology(ax,projection=True)
AxionPhoton.StellarBounds(ax)
AxionPhoton.Haloscopes(ax,projection=True)
AxionPhoton.Helioscopes(ax,fs=23,projection=True)
AxionPhoton.LSW(ax,projection=True)
AxionPhoton.AstroBounds(ax,projection=True)
AxionPhoton.NeutronStars(ax)
BlackHoleSpins(ax,(1/137)*(1/(2*pi)),[5e-12,5e-17],rotation=-90)

MySaveFig(fig,'AxionPhoton_with_Projections')
# Out:
# /Users/Ace/Desktop/AxionLimits/PlotFuncs.py:82: MatplotlibDeprecationWarning: Support for setting the 'text.latex.preamble' or 'pgf.preamble' rcParam to a list of strings is deprecated since 3.3 and will be removed two minor releases later; set it to a single string instead.
#   mpl.rcParams['text.latex.preamble'] = [r'\usepackage{mathpazo}']
# /Users/Ace/Desktop/AxionLimits/PlotFuncs.py:150: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("YlOrBr").copy()
#   cols.set_under('w') # Set lowest color to white
# /Users/Ace/Desktop/AxionLimits/PlotFuncs.py:1012: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   plt.plot([2.1e3,3.5e3],[0.3e-18,0.4e-18],'k-',lw=2.5,color=XRAY_col)

# %%
# %matplotlib inline
from numpy import *
import matplotlib.pyplot as plt
from PlotFuncs import BlackHoleSpins, AxionPhoton, MySaveFig


fig,ax = AxionPhoton.FigSetup(Shape='Wide',ylab='$|C_{a\gamma}|$',mathpazo=True,
                g_min=0.01,g_max=10000000.0,m_min=1e-9,m_max=1,
                 tickdir='in',TopAndRightTicks=True)

AxionPhoton.QCDAxion(ax,RescaleByMass=True,fs=20,KSVZ_on=False,DFSZ_on=True)
AxionPhoton.QCDAxion_NonAbelianMonopole(ax,RescaleByMass=True)
AxionPhoton.ADMX(ax,fs=25,RescaleByMass=True,projection=True)
AxionPhoton.RBF_UF(ax,fs=20,RescaleByMass=True)
AxionPhoton.HAYSTAC(ax,fs=15,RescaleByMass=True,col='violet')
AxionPhoton.CAPP(ax,fs=17,RescaleByMass=True,col='deeppink')
AxionPhoton.ABRACADABRA(ax,fs=20,RescaleByMass=True,projection=True)
AxionPhoton.QUAX(ax,fs=17,RescaleByMass=True)
AxionPhoton.RADES(ax,fs=12,RescaleByMass=True)
AxionPhoton.MADMAX(ax,fs=20,RescaleByMass=True)
AxionPhoton.ALPHA(ax,fs=20,RescaleByMass=True)
AxionPhoton.ORGAN(ax,fs=20,RescaleByMass=True,projection=True)
AxionPhoton.KLASH(ax,fs=20,RescaleByMass=True)
AxionPhoton.BRASS(ax,fs=18,RescaleByMass=True)
AxionPhoton.TOORAD(ax,fs=12,RescaleByMass=True)
AxionPhoton.LAMPOST(ax,fs=18,RescaleByMass=True)
AxionPhoton.NeutronStars(ax,fs=25,RescaleByMass=True)
AxionPhoton.ALPS(ax,projection=True,RescaleByMass=True)
AxionPhoton.Helioscopes(ax,col='royalblue',fs=35,projection=True,RescaleByMass=True)


MySaveFig(fig,'AxionPhoton_Rescaled')
# Out:
# /Users/Ace/Desktop/AxionLimits/PlotFuncs.py:82: MatplotlibDeprecationWarning: Support for setting the 'text.latex.preamble' or 'pgf.preamble' rcParam to a list of strings is deprecated since 3.3 and will be removed two minor releases later; set it to a single string instead.
#   mpl.rcParams['text.latex.preamble'] = [r'\usepackage{mathpazo}']
# /Users/Ace/Desktop/AxionLimits/PlotFuncs.py:185: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("YlOrBr").copy()
#   cols.set_under('w') # Set lowest color to white

# %%
# %matplotlib inline
from numpy import *
import matplotlib.pyplot as plt
from PlotFuncs import BlackHoleSpins, AxionPhoton, MySaveFig

fig,ax = AxionPhoton.FigSetup(Shape='Wide',ylab='$E/N - 1.92$',mathpazo=True,
                g_min=0.01,g_max=10000000.0,m_min=1e-9,m_max=1,
                 tickdir='in',TopAndRightTicks=True)

AxionPhoton.QCDAxion(ax,RescaleByMass=True,fs=20,text_on=False,DFSZ_on=False,KSVZ_on=False)
AxionPhoton.QCDAxion_NonAbelianMonopole(ax,RescaleByMass=True)
AxionPhoton.ADMX(ax,fs=25,RescaleByMass=True,projection=False)
AxionPhoton.RBF_UF(ax,fs=20,RescaleByMass=True)
AxionPhoton.HAYSTAC(ax,fs=15,RescaleByMass=True,col='violet')
AxionPhoton.CAPP(ax,fs=17,RescaleByMass=True,col='deeppink')
AxionPhoton.ABRACADABRA(ax,fs=20,RescaleByMass=True,projection=False)
AxionPhoton.RADES(ax,fs=12,RescaleByMass=True)
AxionPhoton.QUAX(ax,fs=17,RescaleByMass=True)
AxionPhoton.ORGAN(ax,fs=20,RescaleByMass=True,projection=False)
AxionPhoton.NeutronStars(ax,fs=25,RescaleByMass=True)
AxionPhoton.Helioscopes(ax,col='royalblue',fs=35,projection=False,RescaleByMass=True)

ax.axhline(44/3-1.92,color='k',lw=5,zorder=0)
ax.axhline(abs(5/3-1.92),color='k',lw=5,zorder=0)
ax.axhline(44/3-1.92,color='orange',lw=3,zorder=0)
ax.axhline(abs(5/3-1.92),color='orange',lw=3,zorder=0)
plt.gcf().text(0.14,0.22,r'$E/N = 5/3$',fontsize=20)
plt.gcf().text(0.14,0.48,r'$E/N = 44/3$',fontsize=20)


MySaveFig(fig,'AxionPhoton_Rescaled_NoProjections')
# Out:
# /Users/Ace/Desktop/AxionLimits/PlotFuncs.py:82: MatplotlibDeprecationWarning: Support for setting the 'text.latex.preamble' or 'pgf.preamble' rcParam to a list of strings is deprecated since 3.3 and will be removed two minor releases later; set it to a single string instead.
#   mpl.rcParams['text.latex.preamble'] = [r'\usepackage{mathpazo}']
# /Users/Ace/Desktop/AxionLimits/PlotFuncs.py:185: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("YlOrBr").copy()
#   cols.set_under('w') # Set lowest color to white
